# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname="C:\\Windows\\Fonts\\malgun.ttf").get_name()
plt.rc("font", family=font_name)

import matplotlib as mlp
mlp.rcParams["axes.unicode_minus"] = False

import xml.etree.ElementTree as et

import urllib.request as req
import requests
import json

import urllib.request as req
from urllib.error import HTTPError, URLError 

from bs4 import BeautifulSoup

from urllib.request import urlopen

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import os
import re

# %%
path = './'
flist = os.listdir(path)
flist
# Out:
# ['.ipynb_checkpoints',
#  'bus&crime_analysis_code.ipynb',
#  'final_bus_gu_year.csv',
#  'final_crime_gu_year.csv',
#  'pricevalues.csv']

# %%
bus = pd.read_csv('final_bus_gu_year.csv', index_col=0)
bus
# Out:
#     자치구별  2018  2019  2020  2021  2022
# 0    강남구   534   548   545   520   823
# 1    강동구   349   385   383   365   573
# 2    강북구   460   448   415   409   454
# 3    강서구   576   603   611   569   801
# 4    관악구   485   485   470   467   638
# 5    광진구   286   292   288   270   380
# 6    구로구   478   513   510   497   720
# 7    금천구   342   362   357   342   540
# 8    노원구   537   544   538   527   736
# 9    도봉구   386   391   366   358   448
# 10  동대문구   318   319   311   303   408
# 11   동작구   460   447   440   437   545
# 12   마포구   569   568   570   563   764
# 13  서대문구   444   446   457   454   542
# 14   서초구   648   649   638   605   962
# 15   성동구   439   442   433   445   502
# 16   성북구   611   604   599   601   670
# 17   송파구   413   429   440   414   716
# 18   양천구   363   365   320   317   491
# 19  영등포구   491   504   494   466   679
# 20   용산구   349   344   327   328   441
# 21   은평구   499   511   501   497   725
# 22   종로구   382   375   374   369   472
# ...

# %%
bus = bus[['자치구별', '2018']]
bus
# Out:
#     자치구별  2018
# 0    강남구   534
# 1    강동구   349
# 2    강북구   460
# 3    강서구   576
# 4    관악구   485
# 5    광진구   286
# 6    구로구   478
# 7    금천구   342
# 8    노원구   537
# 9    도봉구   386
# 10  동대문구   318
# 11   동작구   460
# 12   마포구   569
# 13  서대문구   444
# 14   서초구   648
# 15   성동구   439
# 16   성북구   611
# 17   송파구   413
# 18   양천구   363
# 19  영등포구   491
# 20   용산구   349
# 21   은평구   499
# 22   종로구   382
# 23    중구   207
# 24   중랑구   379

# %%
apart = pd.read_csv('C:/acorn/MidtermProject/프로젝트/SeokwonNa/apt_buysell_price_2018-22/save_point3_apt_buysell_2018_data.csv')
apart
# Out:
#     자치구별    계약연도  계약월  전용면적(㎡)  거래금액(만원)  1m^2 전용면적당 거래금액(만원)
# 0    강남구  2018.0  5.0     94.0  153334.0               1702.0
# 1    강동구  2018.0  5.0     78.0   64967.0                858.0
# 2    강북구  2018.0  6.0     78.0   42267.0                563.0
# 3    강서구  2018.0  5.0     75.0   53063.0                728.0
# 4    관악구  2018.0  5.0     77.0   47147.0                642.0
# 5    광진구  2018.0  5.0     87.0   80294.0                943.0
# 6    구로구  2018.0  6.0     74.0   43341.0                595.0
# 7    금천구  2018.0  6.0     76.0   37864.0                516.0
# 8    노원구  2018.0  6.0     66.0   38808.0                601.0
# 9    도봉구  2018.0  6.0     72.0   35758.0                504.0
# 10  동대문구  2018.0  5.0     76.0   50636.0                693.0
# 11   동작구  2018.0  5.0     84.0   70567.0                880.0
# 12   마포구  2018.0  5.0     81.0   78185.0                989.0
# 13  서대문구  2018.0  5.0     80.0   56398.0                727.0
# ...

# %%
apart = apart[['자치구별', '1m^2 전용면적당 거래금액(만원)']]
apart.drop(index=25, inplace=True)
# Out:
# C:\Users\khg08\AppData\Local\Temp\ipykernel_35340\1435953782.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apart.drop(index=25, inplace=True)

# %%
apart
# Out:
#     자치구별  1m^2 전용면적당 거래금액(만원)
# 0    강남구               1702.0
# 1    강동구                858.0
# 2    강북구                563.0
# 3    강서구                728.0
# 4    관악구                642.0
# 5    광진구                943.0
# 6    구로구                595.0
# 7    금천구                516.0
# 8    노원구                601.0
# 9    도봉구                504.0
# 10  동대문구                693.0
# 11   동작구                880.0
# 12   마포구                989.0
# 13  서대문구                727.0
# 14   서초구               1461.0
# 15   성동구               1048.0
# 16   성북구                629.0
# 17   송파구               1201.0
# 18   양천구                811.0
# 19  영등포구                845.0
# 20   용산구               1200.0
# 21   은평구                627.0
# 22   종로구                764.0
# 23    중구                871.0
# 24   중랑구                541.0

# %%
df1 = pd.merge(bus, apart)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35340\292095008.py in <module>
# ----> 1 df1 = pd.merge(bus, apart)
#
# NameError: name 'bus' is not defined

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35340\3309751900.py in <module>
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
x = df['2018'].values
y = df['1m^2 전용면적당 거래금액(만원)'].values

# %%
plt.scatter(x, y, alpha=0.5)
plt.title('price ~ bus_stop')
plt.xlabel('bus_stop')
plt.ylabel('price')
plt.show()

# %%
np.corrcoef(x, y)[0,1]
# Out:
# 0.18889036455765798

# %% [markdown]
# ## 범죄

# %%
apart = pd.read_csv('C:/acorn/MidtermProject/프로젝트/SeokwonNa/apt_buysell_price_2018-22/save_point3_apt_buysell_2021_data.csv')
apart = apart[['자치구별', '1m^2 전용면적당 거래금액(만원)']]
apart.drop(index=25, inplace=True)

# %%
crime = pd.read_csv('final_crime_gu_year.csv')
crime
# Out:
#    자치구별  2018  2019  2020  2021
# 0    종로   364   370   272   271
# 1    중구   357   314   283   282
# 2    용산   417   362   319   248
# 3    성동   204   205   171   220
# 4    광진   363   415   352   325
# 5   동대문   243   249   244   282
# 6    중랑   238   212   276   273
# 7    성북   303   259   212   222
# 8    강북   273   239   217   222
# 9    도봉   177   136   131   131
# 10   노원   293   272   236   293
# 11   은평   312   283   251   293
# 12  서대문   278   268   251   292
# 13   마포   735   673   577   524
# 14   양천   193   199   189   202
# 15   강서   424   442   410   434
# 16   구로   405   363   344   341
# 17   금천   273   221   183   246
# 18  영등포   592   520   484   480
# 19   동작   416   367   305   304
# 20   관악   545   579   557   528
# 21   서초   635   785   578   540
# 22   강남  1010  1280  1048   946
# 23   송파   515   459   444   496
# 24   강동   241   280   289   234

# %%
crime['자치구별']=crime['자치구별'] + '구'

# %%
crime
# Out:
#     자치구별  2018  2019  2020  2021
# 0    종로구   364   370   272   271
# 1    중구구   357   314   283   282
# 2    용산구   417   362   319   248
# 3    성동구   204   205   171   220
# 4    광진구   363   415   352   325
# 5   동대문구   243   249   244   282
# 6    중랑구   238   212   276   273
# 7    성북구   303   259   212   222
# 8    강북구   273   239   217   222
# 9    도봉구   177   136   131   131
# 10   노원구   293   272   236   293
# 11   은평구   312   283   251   293
# 12  서대문구   278   268   251   292
# 13   마포구   735   673   577   524
# 14   양천구   193   199   189   202
# 15   강서구   424   442   410   434
# 16   구로구   405   363   344   341
# 17   금천구   273   221   183   246
# 18  영등포구   592   520   484   480
# 19   동작구   416   367   305   304
# 20   관악구   545   579   557   528
# 21   서초구   635   785   578   540
# 22   강남구  1010  1280  1048   946
# 23   송파구   515   459   444   496
# 24   강동구   241   280   289   234

# %%
crime = crime[['자치구별', '2021']]
crime
# Out:
#     자치구별  2021
# 0    종로구   271
# 1    중구구   282
# 2    용산구   248
# 3    성동구   220
# 4    광진구   325
# 5   동대문구   282
# 6    중랑구   273
# 7    성북구   222
# 8    강북구   222
# 9    도봉구   131
# 10   노원구   293
# 11   은평구   293
# 12  서대문구   292
# 13   마포구   524
# 14   양천구   202
# 15   강서구   434
# 16   구로구   341
# 17   금천구   246
# 18  영등포구   480
# 19   동작구   304
# 20   관악구   528
# 21   서초구   540
# 22   강남구   946
# 23   송파구   496
# 24   강동구   234

# %%
crimeapart = pd.merge(crime, apart)
crimeapart
# Out:
#     자치구별  2021  1m^2 전용면적당 거래금액(만원)
# 0    종로구   271               1239.0
# 1    용산구   248               1903.0
# 2    성동구   220               1806.0
# 3    광진구   325               1517.0
# 4   동대문구   282               1174.0
# 5    중랑구   273                969.0
# 6    성북구   222               1144.0
# 7    강북구   222                939.0
# 8    도봉구   131                899.0
# 9    노원구   293               1116.0
# 10   은평구   293               1042.0
# 11  서대문구   292               1256.0
# 12   마포구   524               1568.0
# 13   양천구   202               1353.0
# 14   강서구   434               1175.0
# 15   구로구   341                945.0
# 16   금천구   246                914.0
# 17  영등포구   480               1378.0
# 18   동작구   304               1670.0
# 19   관악구   528               1089.0
# 20   서초구   540               2208.0
# 21   강남구   946               2351.0
# 22   송파구   496               1983.0
# 23   강동구   234               1437.0

# %%
x = crimeapart['2021'].values
y = crimeapart['1m^2 전용면적당 거래금액(만원)'].values

# %%
plt.scatter(x, y, alpha=0.5)
plt.title('2018')
plt.xlabel('crime')
plt.ylabel('price')
plt.show()

# %%
np.corrcoef(x, y)[0,1]
# Out:
# 0.7205499836843302

# %%
plt.scatter(x, y, alpha=0.5)
plt.title('2019')
plt.xlabel('crime')
plt.ylabel('price')
plt.show()

# %%
np.corrcoef(x, y)[0,1]
# Out:
# 0.772857774936406

# %%
plt.scatter(x, y, alpha=0.5)
plt.title('2020')
plt.xlabel('crime')
plt.ylabel('price')
plt.show()

# %%
np.corrcoef(x, y)[0,1]
# Out:
# 0.6856658789874222

# %%
plt.scatter(x, y, alpha=0.5)
plt.title('2021')
plt.xlabel('crime')
plt.ylabel('price')
plt.show()

# %%
np.corrcoef(x, y)[0,1]
# Out:
# 0.6040067318510609

# %%
x = x.loc[0][1:]
x = x.astype('int64')

# %%
apart_gu_year_mean = pd.read_csv(flist[1], index_col=0)
apart_gu_year_mean
# Out:
#    자치구별      본번     부번  전용면적(㎡)      계약년월  거래금액(만원)  1m^2 전용면적당 거래금액(만원)  \
# 0   강남구   479.0    5.0     94.0  201805.0  153334.0               1702.0
# 1   강동구   376.0    4.0     78.0  201805.0   64967.0                858.0
# 2   강북구   768.0    8.0     78.0  201806.0   42267.0                563.0
# 3   강서구   795.0    6.0     75.0  201805.0   53063.0                728.0
# 4   관악구  1497.0   11.0     77.0  201805.0   47147.0                642.0
# ..  ...     ...    ...      ...       ...       ...                  ...
# 21  은평구   306.0   10.0     64.0  202206.0   65036.0               1056.0
# 22  종로구   261.0    7.0     54.0  202205.0   68236.0               1175.0
# 23   중구   578.0  126.0     60.0  202206.0   74575.0               1217.0
# 24  중랑구   427.0   13.0     50.0  202205.0   48790.0                994.0
# 25   평균   554.0   14.0     67.0  202206.0   95151.0               1340.0
#
#       계약연도  계약월
# 0   2018.0  5.0
# 1   2018.0  5.0
# 2   2018.0  6.0
# 3   2018.0  5.0
# ...

# %%
y = y[(y['자치구별']=='강남구')]
y = y['1m^2 전용면적당 거래금액(만원)']
y = y.astype('int64')
# Out:
#   자치구별     본번   부번  전용면적(㎡)      계약년월  거래금액(만원)  1m^2 전용면적당 거래금액(만원)    계약연도  \
# 0  강남구  479.0  5.0     94.0  201805.0  153334.0               1702.0  2018.0
# 0  강남구  494.0  4.0     92.0  201908.0  179961.0               2051.0  2019.0
# 0  강남구  496.0  4.0     88.0  202007.0  183946.0               2117.0  2020.0
# 0  강남구  498.0  5.0     88.0  202105.0  207220.0               2351.0  2021.0
# 0  강남구  480.0  6.0     85.0  202206.0  207409.0               2296.0  2022.0
#
#    계약월
# 0  5.0
# 0  8.0
# 0  7.0
# 0  5.0
# 0  6.0

# %%
plt.scatter(x, y, alpha=0.5)

# %%
for i in range(len(bus_gu_year_mean)) :
    x = bus_gu_year_mean.loc[i][1:].astype('int64')
    y = apart_gu_year_mean[(apart_gu_year_mean['자치구별'] == bus_gu_year_mean['자치구별'][i])]
    y = y['1m^2 전용면적당 거래금액(만원)'].astype('int64')
    print(np.corrcoef(x, y))
    print(bus_gu_year_mean['자치구별'][i])
    print('\n')
# Out:
# [[1.         0.39204194]
#  [0.39204194 1.        ]]
# 강남구
#
#
# [[1.         0.41965631]
#  [0.41965631 1.        ]]
# 강동구
#
#
# [[ 1.         -0.49343926]
#  [-0.49343926  1.        ]]
# 강북구
#
#
# [[1.         0.23319709]
#  [0.23319709 1.        ]]
# 강서구
#
#
# [[1.         0.39234627]
#  [0.39234627 1.        ]]
# 관악구
#
#
# [[1.         0.26371931]
#  [0.26371931 1.        ]]
# 광진구
#
#
# [[1.         0.44971145]
#  [0.44971145 1.        ]]
# 구로구
#
#
# [[1.         0.67442528]
#  [0.67442528 1.        ]]
# 금천구
#
#
# [[1.         0.52377534]
#  [0.52377534 1.        ]]
# 노원구
#
#
# [[1.         0.23795466]
#  [0.23795466 1.        ]]
# 도봉구
#
#
# [[1.         0.28360089]
#  [0.28360089 1.        ]]
# 동대문구
#
#
# [[1.         0.13791278]
#  [0.13791278 1.        ]]
# 동작구
#
#
# [[1.         0.50332446]
#  [0.50332446 1.        ]]
# 마포구
#
#
# [[1.         0.56426707]
#  [0.56426707 1.        ]]
# 서대문구
#
#
# [[1.         0.54606584]
#  [0.54606584 1.        ]]
# 서초구
#
#
# ...

# %%
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.39204194],
#        [0.39204194, 1.        ]])

# %%
stats

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
pricevalues = pd.read_csv('pricevalues.csv', index_col=0)
pricevalues
# Out:
#       자치구별      번지      본번    부번             단지명  전용면적(㎡)    계약년월  거래금액(만원)  \
# 0      강남구   658-1   658.0   1.0  개포6차우성아파트1동~8동    79.97  202204    220000
# 1      강남구   658-1   658.0   1.0  개포6차우성아파트1동~8동    79.97  202204    220000
# 2      강남구   658-1   658.0   1.0  개포6차우성아파트1동~8동    79.97  202205    216000
# 3      강남구    1282  1282.0   0.0       개포래미안포레스트   102.32  202204    369000
# 4      강남구    1282  1282.0   0.0       개포래미안포레스트   136.06  202205    420000
# ...    ...     ...     ...   ...             ...      ...     ...       ...
# 12670  중랑구     450   450.0   0.0  한신아파트(103~109)    59.76  202203     73000
# 12671  중랑구     450   450.0   0.0  한신아파트(103~109)    59.76  202207     74000
# 12672  중랑구     450   450.0   0.0  한신아파트(103~109)    84.03  202207     91500
# 12673  중랑구  274-51   274.0  51.0         한영(101)    84.69  202204     49900
# 12674  중랑구    11-7    11.0   7.0     현대휴앤미(102동)    76.43  202204     53000
#
#        1m^2 전용면적당 거래금액(만원)  계약연도  계약월
# ...

# %%
gangnam_prices = pricevalues[pricevalues['자치구별']=='강남구']
gangnam_prices
# Out:
#     자치구별      번지      본번    부번             단지명  전용면적(㎡)    계약년월  거래금액(만원)  \
# 0    강남구   658-1   658.0   1.0  개포6차우성아파트1동~8동   79.970  202204    220000
# 1    강남구   658-1   658.0   1.0  개포6차우성아파트1동~8동   79.970  202204    220000
# 2    강남구   658-1   658.0   1.0  개포6차우성아파트1동~8동   79.970  202205    216000
# 3    강남구    1282  1282.0   0.0       개포래미안포레스트  102.320  202204    369000
# 4    강남구    1282  1282.0   0.0       개포래미안포레스트  136.060  202205    420000
# ..   ...     ...     ...   ...             ...      ...     ...       ...
# 819  강남구  134-38   134.0  38.0            청담자이   49.639  202209    225000
# 820  강남구  127-31   127.0  31.0       청담현대3차아파트  109.530  202210    294000
# 821  강남구  101-17   101.0  17.0   효성빌라청담101(B동)  226.620  202204    747000
# 822  강남구    5-25     5.0  25.0           휴먼스타빌   35.905  202202     80000
# 823  강남구    5-25     5.0  25.0           휴먼스타빌   35.905  202212     90000
#
#      1m^2 전용면적당 거래금액(만원)  계약연도  계약월
# 0                   2751  2022    4
# ...

# %%
y = gangnam_prices['1m^2 전용면적당 거래금액(만원)']

# %% [markdown]
# ## 범죄&매매 y축 2개

# %%
crime = pd.read_csv('C:/acorn/midproject/crimerate/final_crime_gu_year.csv')
crime
# Out:
#    자치구별  2018  2019  2020  2021
# 0    종로   364   370   272   271
# 1    중구   357   314   283   282
# 2    용산   417   362   319   248
# 3    성동   204   205   171   220
# 4    광진   363   415   352   325
# 5   동대문   243   249   244   282
# 6    중랑   238   212   276   273
# 7    성북   303   259   212   222
# 8    강북   273   239   217   222
# 9    도봉   177   136   131   131
# 10   노원   293   272   236   293
# 11   은평   312   283   251   293
# 12  서대문   278   268   251   292
# 13   마포   735   673   577   524
# 14   양천   193   199   189   202
# 15   강서   424   442   410   434
# 16   구로   405   363   344   341
# 17   금천   273   221   183   246
# 18  영등포   592   520   484   480
# 19   동작   416   367   305   304
# 20   관악   545   579   557   528
# 21   서초   635   785   578   540
# 22   강남  1010  1280  1048   946
# 23   송파   515   459   444   496
# 24   강동   241   280   289   234

# %%
crime['mean'] = (crime['2018'] + crime['2019'] + crime['2020'] + crime['2021']) / 4

# %%
crime
# Out:
#    자치구별  2018  2019  2020  2021     mean
# 0    종로   364   370   272   271   319.25
# 1    중구   357   314   283   282   309.00
# 2    용산   417   362   319   248   336.50
# 3    성동   204   205   171   220   200.00
# 4    광진   363   415   352   325   363.75
# 5   동대문   243   249   244   282   254.50
# 6    중랑   238   212   276   273   249.75
# 7    성북   303   259   212   222   249.00
# 8    강북   273   239   217   222   237.75
# 9    도봉   177   136   131   131   143.75
# 10   노원   293   272   236   293   273.50
# 11   은평   312   283   251   293   284.75
# 12  서대문   278   268   251   292   272.25
# 13   마포   735   673   577   524   627.25
# 14   양천   193   199   189   202   195.75
# 15   강서   424   442   410   434   427.50
# 16   구로   405   363   344   341   363.25
# 17   금천   273   221   183   246   230.75
# 18  영등포   592   520   484   480   519.00
# 19   동작   416   367   305   304   348.00
# 20   관악   545   579   557   528   552.25
# 21   서초   635   785   578   540   634.50
# ...

# %%
crime_long = pd.melt(crime, id_vars=['자치구별'], var_name='year', value_name='crime_num')
crime_long
# Out:
#    자치구별  year  crime_num
# 0    종로  2018        364
# 1    중구  2018        357
# 2    용산  2018        417
# 3    성동  2018        204
# 4    광진  2018        363
# ..  ...   ...        ...
# 95   관악  2021        528
# 96   서초  2021        540
# 97   강남  2021        946
# 98   송파  2021        496
# 99   강동  2021        234
#
# [100 rows x 3 columns]

# %%
crime_long['자치구별'] = crime_long['자치구별'] + '구'

# %%
price = pd.read_csv('C:/acorn/MidtermProject/프로젝트/SeokwonNa/apt_buysell_price_2018-22/save_point3_apt_buysell_2018_data.csv')
price
# Out:
#     자치구별    계약연도  계약월  전용면적(㎡)  거래금액(만원)  1m^2 전용면적당 거래금액(만원)
# 0    강남구  2018.0  5.0     94.0  153334.0               1702.0
# 1    강동구  2018.0  5.0     78.0   64967.0                858.0
# 2    강북구  2018.0  6.0     78.0   42267.0                563.0
# 3    강서구  2018.0  5.0     75.0   53063.0                728.0
# 4    관악구  2018.0  5.0     77.0   47147.0                642.0
# 5    광진구  2018.0  5.0     87.0   80294.0                943.0
# 6    구로구  2018.0  6.0     74.0   43341.0                595.0
# 7    금천구  2018.0  6.0     76.0   37864.0                516.0
# 8    노원구  2018.0  6.0     66.0   38808.0                601.0
# 9    도봉구  2018.0  6.0     72.0   35758.0                504.0
# 10  동대문구  2018.0  5.0     76.0   50636.0                693.0
# 11   동작구  2018.0  5.0     84.0   70567.0                880.0
# 12   마포구  2018.0  5.0     81.0   78185.0                989.0
# 13  서대문구  2018.0  5.0     80.0   56398.0                727.0
# ...

# %%
p2018 = price[['자치구별', '1m^2 전용면적당 거래금액(만원)']]
p2018
# Out:
#     자치구별  1m^2 전용면적당 거래금액(만원)
# 0    강남구               1702.0
# 1    강동구                858.0
# 2    강북구                563.0
# 3    강서구                728.0
# 4    관악구                642.0
# 5    광진구                943.0
# 6    구로구                595.0
# 7    금천구                516.0
# 8    노원구                601.0
# 9    도봉구                504.0
# 10  동대문구                693.0
# 11   동작구                880.0
# 12   마포구                989.0
# 13  서대문구                727.0
# 14   서초구               1461.0
# 15   성동구               1048.0
# 16   성북구                629.0
# 17   송파구               1201.0
# 18   양천구                811.0
# 19  영등포구                845.0
# 20   용산구               1200.0
# 21   은평구                627.0
# 22   종로구                764.0
# 23    중구                871.0
# 24   중랑구                541.0
# 25    평균                838.0

# %%
all = pd.merge(c2018, p2018)
all
# Out:
#     자치구별  2018  1m^2 전용면적당 거래금액(만원)
# 0    종로구   364                764.0
# 1    용산구   417               1200.0
# 2    성동구   204               1048.0
# 3    광진구   363                943.0
# 4   동대문구   243                693.0
# 5    중랑구   238                541.0
# 6    성북구   303                629.0
# 7    강북구   273                563.0
# 8    도봉구   177                504.0
# 9    노원구   293                601.0
# 10   은평구   312                627.0
# 11  서대문구   278                727.0
# 12   마포구   735                989.0
# 13   양천구   193                811.0
# 14   강서구   424                728.0
# 15   구로구   405                595.0
# 16   금천구   273                516.0
# 17  영등포구   592                845.0
# 18   동작구   416                880.0
# 19   관악구   545                642.0
# 20   서초구   635               1461.0
# 21   강남구  1010               1702.0
# 22   송파구   515               1201.0
# 23   강동구   241                858.0

# %% [markdown]
# ## long형

# %%
path = 'C:/acorn/MidtermProject/프로젝트/SeokwonNa/apt_buysell_price_2018-22/'
flist = os.listdir(path)
flist
# Out:
# ['apt_buysell_2018-2022_preprocessingdata.csv',
#  'save_point1_apt_buysell_2018_data.csv',
#  'save_point1_apt_buysell_2019_data.csv',
#  'save_point1_apt_buysell_2020_data.csv',
#  'save_point1_apt_buysell_2021_data.csv',
#  'save_point1_apt_buysell_2022_data.csv',
#  'save_point2_apt_buysell_2018_data.csv',
#  'save_point2_apt_buysell_2019_data.csv',
#  'save_point2_apt_buysell_2020_data.csv',
#  'save_point2_apt_buysell_2021_data.csv',
#  'save_point2_apt_buysell_2022_data.csv',
#  'save_point3_apt_buysell_2018_data.csv',
#  'save_point3_apt_buysell_2019_data.csv',
#  'save_point3_apt_buysell_2020_data.csv',
#  'save_point3_apt_buysell_2021_data.csv',
#  'save_point3_apt_buysell_2022_data.csv']

# %%
pattern = re.compile('point3')

for i in flist:
    if pattern.match(i) :
        print(i)

# %%
df1 = pd.read_csv(path+flist[-5])
df1.drop(index=25, inplace=True)
df2 = pd.read_csv(path+flist[-4])
df2.drop(index=25, inplace=True)
df3 = pd.read_csv(path+flist[-3])
df3.drop(index=25, inplace=True)
df4 = pd.read_csv(path+flist[-2])
df4.drop(index=25, inplace=True)

# %%
df = pd.concat([df1, df2, df3, df4])
df
# Out:
#    자치구별    계약연도  계약월  전용면적(㎡)  거래금액(만원)  1m^2 전용면적당 거래금액(만원)
# 0   강남구  2018.0  5.0     94.0  153334.0               1702.0
# 1   강동구  2018.0  5.0     78.0   64967.0                858.0
# 2   강북구  2018.0  6.0     78.0   42267.0                563.0
# 3   강서구  2018.0  5.0     75.0   53063.0                728.0
# 4   관악구  2018.0  5.0     77.0   47147.0                642.0
# ..  ...     ...  ...      ...       ...                  ...
# 20  용산구  2021.0  5.0    104.0  199106.0               1903.0
# 21  은평구  2021.0  6.0     73.0   73155.0               1042.0
# 22  종로구  2021.0  6.0     75.0   92945.0               1239.0
# 23   중구  2021.0  5.0     70.0   89991.0               1285.0
# 24  중랑구  2021.0  6.0     68.0   64494.0                969.0
#
# [100 rows x 6 columns]

# %%
df = df[['자치구별', '계약연도', '1m^2 전용면적당 거래금액(만원)']]

# %%
df.rename(columns={'계약연도':'year'}, inplace=True)
# Out:
# C:\Users\khg08\AppData\Local\Temp\ipykernel_35340\1187835345.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'계약연도':'year'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 24
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   자치구별                 100 non-null    object
#  1   year                 100 non-null    float64
#  2   1m^2 전용면적당 거래금액(만원)  100 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 3.1+ KB

# %%
df.year = df.year.astype(int).astype(str)
# Out:
# C:\Users\khg08\AppData\Local\Temp\ipykernel_35340\3117748969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.year = df.year.astype(int).astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 24
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   자치구별                 100 non-null    object
#  1   year                 100 non-null    object
#  2   1m^2 전용면적당 거래금액(만원)  100 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 3.1+ KB

# %%
crime_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   자치구별       100 non-null    object
#  1   year       100 non-null    object
#  2   crime_num  100 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 2.5+ KB

# %%
crime_long.head(25)
# Out:
#     자치구별  year  crime_num
# 0    종로구  2018        364
# 1    중구구  2018        357
# 2    용산구  2018        417
# 3    성동구  2018        204
# 4    광진구  2018        363
# 5   동대문구  2018        243
# 6    중랑구  2018        238
# 7    성북구  2018        303
# 8    강북구  2018        273
# 9    도봉구  2018        177
# 10   노원구  2018        293
# 11   은평구  2018        312
# 12  서대문구  2018        278
# 13   마포구  2018        735
# 14   양천구  2018        193
# 15   강서구  2018        424
# 16   구로구  2018        405
# 17   금천구  2018        273
# 18  영등포구  2018        592
# 19   동작구  2018        416
# 20   관악구  2018        545
# 21   서초구  2018        635
# 22   강남구  2018       1010
# 23   송파구  2018        515
# 24   강동구  2018        241

# %%
df.head()
# Out:
#   자치구별  year  1m^2 전용면적당 거래금액(만원)
# 0  강남구  2018               1702.0
# 1  강동구  2018                858.0
# 2  강북구  2018                563.0
# 3  강서구  2018                728.0
# 4  관악구  2018                642.0

# %%
concat = pd.merge(df, crime_long, on = ['자치구별', 'year'])
concat
# Out:
#     자치구별  year  1m^2 전용면적당 거래금액(만원)  crime_num
# 0    강남구  2018               1702.0       1010
# 1    강동구  2018                858.0        241
# 2    강북구  2018                563.0        273
# 3    강서구  2018                728.0        424
# 4    관악구  2018                642.0        545
# ..   ...   ...                  ...        ...
# 91  영등포구  2021               1378.0        480
# 92   용산구  2021               1903.0        248
# 93   은평구  2021               1042.0        293
# 94   종로구  2021               1239.0        271
# 95   중랑구  2021                969.0        273
#
# [96 rows x 4 columns]

# %%
x = concat['crime_num'].values
y = concat['1m^2 전용면적당 거래금액(만원)'].values

# %%
np.corrcoef(x, y)[0,1]
# Out:
# 0.5538582210650094

# %%
concat[concat.year=='2018']
# Out:
#     자치구별  year  1m^2 전용면적당 거래금액(만원)  crime_num
# 0    강남구  2018               1702.0       1010
# 1    강동구  2018                858.0        241
# 2    강북구  2018                563.0        273
# 3    강서구  2018                728.0        424
# 4    관악구  2018                642.0        545
# 5    광진구  2018                943.0        363
# 6    구로구  2018                595.0        405
# 7    금천구  2018                516.0        273
# 8    노원구  2018                601.0        293
# 9    도봉구  2018                504.0        177
# 10  동대문구  2018                693.0        243
# 11   동작구  2018                880.0        416
# 12   마포구  2018                989.0        735
# 13  서대문구  2018                727.0        278
# 14   서초구  2018               1461.0        635
# 15   성동구  2018               1048.0        204
# 16   성북구  2018                629.0        303
# 17   송파구  2018               1201.0        515
# 18   양천구  2018                811.0        193
# ...

# %%
concat.to_csv('C:/acorn/midproject/R분석/범죄가격4년치.csv')
