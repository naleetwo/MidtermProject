# %% [markdown]
# #### 기준년도 : 2021년

# %%
import pandas as pd

# %%
aca=pd.read_csv("C:\\Users\\owner\\Desktop\\데이터 분석 중간 프로젝트\\인프라\\사설학원+및+독서실(2009년+이후)_20230412182920.csv",header=4)

# %%
aca
# Out:
#    자치구별(1) 자치구별(2)     소계   소계.1  입시검정 및 보습  국제화    예능  특수교육   종합   기타  소계.2  \
# 0       합계      소계  13809  11647       7771  753  2277     1  322  523  2162
# 1       합계     종로구    217     91         63    6    13     0    3    6   126
# 2       합계      중구     91     47         26    9     8     0    1    3    44
# 3       합계     용산구    137    116         63   21    26     0    4    2    21
# 4       합계     성동구    290    247        153   14    55     0   16    9    43
# 5       합계     광진구    426    364        247   23    68     0    7   19    62
# 6       합계    동대문구    359    308        203   16    78     0    4    7    51
# 7       합계     중랑구    257    232        159    6    48     0   10    9    25
# 8       합계     성북구    451    430        296   19   101     0    4   10    21
# 9       합계     강북구    210    187        139    3    38     0    4    3    23
# 10      합계     도봉구    285    268        197   12    51     0    2    6    17
# ...

# %%
aca1=aca[["자치구별(2)","소계.1","소계.2"]]

# %%
aca1.columns=["자치구별","학교교과학원수","평생교육학원수"]

# %%
aca1.drop(0,inplace=True)
# Out:
# C:\Users\owner\AppData\Local\Temp\ipykernel_5980\3874090698.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aca1.drop(0,inplace=True)

# %%
aca1
# Out:
#     자치구별  학교교과학원수  평생교육학원수
# 1    종로구       91      126
# 2     중구       47       44
# 3    용산구      116       21
# 4    성동구      247       43
# 5    광진구      364       62
# 6   동대문구      308       51
# 7    중랑구      232       25
# 8    성북구      430       21
# 9    강북구      187       23
# 10   도봉구      268       17
# 11   노원구      636       48
# 12   은평구      472       37
# 13  서대문구      287       55
# 14   마포구      499      193
# 15   양천구      947       32
# 16   강서구      649       48
# 17   구로구      345       41
# 18   금천구      175       33
# 19  영등포구      315      125
# 20   동작구      345      142
# 21   관악구      336       98
# 22   서초구      876      270
# 23   강남구     1898      485
# 24   송파구      963       82
# 25   강동구      614       40

# %%
aca1.set_index(["자치구별"],inplace=True)

# %%
aca1["학원총합계"]=aca1["학교교과학원수"]+aca1["평생교육학원수"]
# Out:
# C:\Users\owner\AppData\Local\Temp\ipykernel_5980\2961539044.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aca1["학원총합계"]=aca1["학교교과학원수"]+aca1["평생교육학원수"]

# %%
academy=aca1

# %%
academy.to_csv("C:\\Users\\owner\\team project\\전처리 완\\academy.csv")
