# %% [markdown]
# ## 출처: https://kosis.kr/statHtml/statHtml.do?orgId=135&tblId=TX_13501_A048&vw_cd=MT_ZTITLE&list_id=135_001_002_001&scrId=&seqNo=&lang_mode=ko&obj_var_id=&itm_id=&conn_path=MT_ZTITLE&path=%252FstatisticsList%252FstatisticsListIndex.do

# %%
import pandas as pd
import numpy as np
import re
import os

# %% [markdown]
# ### 살인,강도,방화,성폭력

# %%
df = pd.read_csv('범죄.csv', encoding='euc-kr',header=2)
df
# Out:
#     발생지별(1)  발생지별(2)    소계  소계.1  소계.2  소계.3    살인  살인.1  살인.2  살인.3  ...  \
# 0   발생지별(1)  발생지별(2)  2018  2019  2020  2021  2018  2019  2020  2021  ...
# 1        서울       소계  9806  9752  8623  8629   152   146   157   127  ...
# 2        서울       종로   364   370   272   271     7     4     8     5  ...
# 3        서울       중구   357   314   283   282     2     5     2     6  ...
# 4        서울       용산   417   362   319   248     1     3     5     3  ...
# 5        서울       성동   204   205   171   220     2     6     5     4  ...
# 6        서울       광진   363   415   352   325     7     4     2     5  ...
# 7        서울      동대문   243   249   244   282     5     7    10     3  ...
# 8        서울       중랑   238   212   276   273     4    10    10     4  ...
# 9        서울       성북   303   259   212   222     8     3     4     4  ...
# 10       서울       강북   273   239   217   222     8     6     9     4  ...
# 11       서울       도봉   177   136   131   131     1     1     -     2  ...
# ...

# %%
df1=df[["발생지별(2)", "소계", "소계.1", "소계.2", "소계.3"]]

# %%
df1
# Out:
#     발생지별(2)    소계  소계.1  소계.2  소계.3
# 0   발생지별(2)  2018  2019  2020  2021
# 1        소계  9806  9752  8623  8629
# 2        종로   364   370   272   271
# 3        중구   357   314   283   282
# 4        용산   417   362   319   248
# 5        성동   204   205   171   220
# 6        광진   363   415   352   325
# 7       동대문   243   249   244   282
# 8        중랑   238   212   276   273
# 9        성북   303   259   212   222
# 10       강북   273   239   217   222
# 11       도봉   177   136   131   131
# 12       노원   293   272   236   293
# 13       은평   312   283   251   293
# 14      서대문   278   268   251   292
# 15       마포   735   673   577   524
# 16       양천   193   199   189   202
# 17       강서   424   442   410   434
# 18       구로   405   363   344   341
# 19       금천   273   221   183   246
# 20      영등포   592   520   484   480
# 21       동작   416   367   305   304
# 22       관악   545   579   557   528
# 23       서초   635   785   578   540
# 24       강남  1010  1280  1048   946
# ...

# %%
df1.columns = df1.loc[0]

# %%
df1.drop([0, 1], inplace=True)
# Out:
# C:\Users\khg08\AppData\Local\Temp\ipykernel_35572\526197053.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop([0, 1], inplace=True)

# %%
df1
# Out:
# 0  발생지별(2)  2018  2019  2020  2021
# 2       종로   364   370   272   271
# 3       중구   357   314   283   282
# 4       용산   417   362   319   248
# 5       성동   204   205   171   220
# 6       광진   363   415   352   325
# 7      동대문   243   249   244   282
# 8       중랑   238   212   276   273
# 9       성북   303   259   212   222
# 10      강북   273   239   217   222
# 11      도봉   177   136   131   131
# 12      노원   293   272   236   293
# 13      은평   312   283   251   293
# 14     서대문   278   268   251   292
# 15      마포   735   673   577   524
# 16      양천   193   199   189   202
# 17      강서   424   442   410   434
# 18      구로   405   363   344   341
# 19      금천   273   221   183   246
# 20     영등포   592   520   484   480
# 21      동작   416   367   305   304
# 22      관악   545   579   557   528
# 23      서초   635   785   578   540
# 24      강남  1010  1280  1048   946
# 25      송파   515   459   444   496
# 26      강동   241   280   289   234

# %%
df1.rename(columns={'발생지별(2)':'자치구별'}, inplace=True)
# Out:
# C:\Users\khg08\AppData\Local\Temp\ipykernel_35572\1723660754.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.rename(columns={'발생지별(2)':'자치구별'}, inplace=True)

# %%
df1.set_index('자치구별', inplace=True)

# %%
df1.to_csv('final_crime_gu_year.csv')
