# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname="C:\\Windows\\Fonts\\malgun.ttf").get_name()
plt.rc("font", family=font_name)

import matplotlib as mlp
mlp.rcParams["axes.unicode_minus"] = False

import xml.etree.ElementTree as et

import urllib.request as req
import requests
import json

import urllib.request as req
from urllib.error import HTTPError, URLError 

from bs4 import BeautifulSoup

from urllib.request import urlopen

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import os
import re

# %%
path = 'C:/acorn/MidtermProject/프로젝트/SeokwonNa/Raw_data/'
flist = os.listdir(path)
flist
# Out:
# ['아파트(매매)__실거래가_2018_국토교통부.csv',
#  '아파트(매매)__실거래가_2019_국토교통부.csv',
#  '아파트(매매)__실거래가_2020_국토교통부.csv',
#  '아파트(매매)__실거래가_2021_국토교통부.csv',
#  '아파트(매매)__실거래가_2022_국토교통부.csv',
#  '아파트(전월세)_실거래가_2018_국토교통부.csv',
#  '아파트(전월세)_실거래가_2019_국토교통부.csv',
#  '아파트(전월세)_실거래가_2020_국토교통부.csv',
#  '아파트(전월세)_실거래가_2021_국토교통부.csv',
#  '아파트(전월세)_실거래가_2022_국토교통부.csv',
#  '지역별_전월세전환율_2018-2022.csv']

# %% [markdown]
# ### 2018년

# %%
pattern = re.compile('매매')
buy = []
for i in flist :
    if re.match(pattern, i) :
        buy.append(i)
buy
# Out:
# []

# %%
raw = pd.read_csv('C:/acorn/MidtermProject/프로젝트/SeokwonNa/Raw_data/아파트(매매)__실거래가_2022_국토교통부.csv', encoding='euc-kr', skiprows=15)
raw
# Out:
#                  시군구      번지      본번    부번             단지명  전용면적(㎡)    계약년월  \
# 0      서울특별시 강남구 개포동   658-1   658.0   1.0  개포6차우성아파트1동~8동    79.97  202204
# 1      서울특별시 강남구 개포동   658-1   658.0   1.0  개포6차우성아파트1동~8동    79.97  202204
# 2      서울특별시 강남구 개포동   658-1   658.0   1.0  개포6차우성아파트1동~8동    79.97  202205
# 3      서울특별시 강남구 개포동    1282  1282.0   0.0       개포래미안포레스트   102.32  202204
# 4      서울특별시 강남구 개포동    1282  1282.0   0.0       개포래미안포레스트   136.06  202205
# ...              ...     ...     ...   ...             ...      ...     ...
# 12670  서울특별시 중랑구 중화동     450   450.0   0.0  한신아파트(103~109)    59.76  202203
# 12671  서울특별시 중랑구 중화동     450   450.0   0.0  한신아파트(103~109)    59.76  202207
# 12672  서울특별시 중랑구 중화동     450   450.0   0.0  한신아파트(103~109)    84.03  202207
# 12673  서울특별시 중랑구 중화동  274-51   274.0  51.0         한영(101)    84.69  202204
# 12674  서울특별시 중랑구 중화동    11-7    11.0   7.0     현대휴앤미(102동)    76.43  202204
#
# ...

# %%
raw['거래금액(만원)'] = raw['거래금액(만원)'].str.replace(',', '').astype('int')

# %%
pre = pd.read_csv('C:/acorn/MidtermProject/프로젝트/SeokwonNa/apt_buysell_price_2018-22/save_point1_apt_buysell_2022_data.csv', index_col=0)
pre
# Out:
#       자치구별  전용면적(㎡)    계약년월  거래금액(만원)  1m^2 전용면적당 거래금액(만원)  계약연도  계약월
# 0      강남구    79.97  202204    220000                 2751  2022    4
# 1      강남구    79.97  202204    220000                 2751  2022    4
# 2      강남구    79.97  202205    216000                 2701  2022    5
# 3      강남구   102.32  202204    369000                 3606  2022    4
# 4      강남구   136.06  202205    420000                 3086  2022    5
# ...    ...      ...     ...       ...                  ...   ...  ...
# 12670  중랑구    59.76  202203     73000                 1221  2022    3
# 12671  중랑구    59.76  202207     74000                 1238  2022    7
# 12672  중랑구    84.03  202207     91500                 1088  2022    7
# 12673  중랑구    84.69  202204     49900                  589  2022    4
# 12674  중랑구    76.43  202204     53000                  693  2022    4
#
# [12675 rows x 7 columns]

# %%
plt.figure(figsize=(25, 10))
sns.boxplot(x='자치구별', y='거래금액(만원)', data=pre)
plt.show()

# %%
raw[raw['거래금액(만원)'] > 1200000]
# Out:
#                    시군구       번지     본번     부번        단지명  전용면적(㎡)    계약년월  \
# 762      서울특별시 강남구 청담동      129  129.0    0.0      PH129  273.960  202204
# 8317   서울특별시 성동구 성수동1가  685-700  685.0  700.0  아크로서울포레스트  264.546  202209
# 11119    서울특별시 용산구 한남동      410  410.0    0.0      파르크한남  268.670  202204
#
#        계약일  거래금액(만원)   층    건축년도           도로명  해제사유발생일  거래유형  중개사소재지
# 762     28   1450000  16  2020.0    압구정로79길 88      NaN   직거래       -
# 8317    30   1300000  47  2020.0    왕십리로 83-21      NaN  중개거래  서울 성동구
# 11119   30   1350000   5  2020.0  유엔빌리지길 80-36      NaN   직거래       -
