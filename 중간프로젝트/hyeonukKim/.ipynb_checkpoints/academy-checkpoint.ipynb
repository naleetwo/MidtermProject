# %% [markdown]
# # 학원데이터
# ## 입시검정 및 보습학원, 국제화 학원, 예능, 특수교육학원 데이터
#     - 데이터 출처 : https://data.seoul.go.kr/dataList/195/S/2/datasetView.do

# %%
import pandas as pd

# %%
a=pd.read_csv("C:\\Users\\owner\\team project\\raw data\\사설학원+및+독서실(2009년+이후)_20230418145558.csv")

# %%
a.head(10)
# Out:
#    자치구별(1)  자치구별(2)     2018     2018.1     2018.2     2018.3     2018.4  \
# 0  자치구별(1)  자치구별(2)     사설학원       사설학원       사설학원       사설학원       사설학원
# 1  자치구별(1)  자치구별(2)  학원수 (개)    학원수 (개)    학원수 (개)    학원수 (개)    학원수 (개)
# 2  자치구별(1)  자치구별(2)       소계  학교교과 교습학원  학교교과 교습학원  학교교과 교습학원  학교교과 교습학원
# 3  자치구별(1)  자치구별(2)       소계         소계  입시검정 및 보습        국제화         예능
# 4       합계      종로구      274        100         73          5         13
# 5       합계       중구      119         57         38          7          8
# 6       합계      용산구      158        128         65         28         27
# 7       합계      성동구      314        268        159         16         69
# 8       합계      광진구      430        367        244         25         76
# 9       합계     동대문구      363        309        198         17         84
#
#       2018.5     2018.6     2018.7  ...     2021.3     2021.4     2021.5  \
# 0       사설학원       사설학원       사설학원  ...       사설학원       사설학원       사설학원
# ...

# %%
a.drop(0,inplace=True)
a.drop(1,inplace=True)
a.drop(2,inplace=True)

# %%
a=a[["자치구별(2)","2018","2019","2020","2021"]]

# %%
a
# Out:
#     자치구별(2)  2018  2019  2020  2021
# 3   자치구별(2)    소계    소계    소계    소계
# 4       종로구   274   259   243   217
# 5        중구   119   118   109    91
# 6       용산구   158   155   154   137
# 7       성동구   314   293   289   290
# 8       광진구   430   406   405   426
# 9      동대문구   363   368   350   359
# 10      중랑구   273   276   262   257
# 11      성북구   464   450   439   451
# 12      강북구   218   209   206   210
# 13      도봉구   335   317   297   285
# 14      노원구   747   740   718   684
# 15      은평구   521   525   519   509
# 16     서대문구   345   346   348   342
# 17      마포구   644   683   689   692
# 18      양천구  1062  1037  1008   979
# 19      강서구   707   693   694   697
# 20      구로구   427   406   394   386
# 21      금천구   222   224   212   208
# 22     영등포구   467   446   445   440
# 23      동작구   458   465   471   487
# 24      관악구   450   443   431   434
# 25      서초구  1130  1119  1148  1146
# 26      강남구  2263  2279  2361  2383
# 27      송파구  1051  1115  1076  1045
# ...

# %%
a.columns=["자치구별","2018학원수","2019학원수","2020학원수","2021학원수"]

# %%
a
# Out:
#        자치구별 2018학원수 2019학원수 2020학원수 2021학원수
# 3   자치구별(2)      소계      소계      소계      소계
# 4       종로구     274     259     243     217
# 5        중구     119     118     109      91
# 6       용산구     158     155     154     137
# 7       성동구     314     293     289     290
# 8       광진구     430     406     405     426
# 9      동대문구     363     368     350     359
# 10      중랑구     273     276     262     257
# 11      성북구     464     450     439     451
# 12      강북구     218     209     206     210
# 13      도봉구     335     317     297     285
# 14      노원구     747     740     718     684
# 15      은평구     521     525     519     509
# 16     서대문구     345     346     348     342
# 17      마포구     644     683     689     692
# 18      양천구    1062    1037    1008     979
# 19      강서구     707     693     694     697
# 20      구로구     427     406     394     386
# 21      금천구     222     224     212     208
# 22     영등포구     467     446     445     440
# ...

# %%
a.drop(3,inplace=True)

# %%
a
# Out:
#     자치구별 2018학원수 2019학원수 2020학원수 2021학원수
# 4    종로구     274     259     243     217
# 5     중구     119     118     109      91
# 6    용산구     158     155     154     137
# 7    성동구     314     293     289     290
# 8    광진구     430     406     405     426
# 9   동대문구     363     368     350     359
# 10   중랑구     273     276     262     257
# 11   성북구     464     450     439     451
# 12   강북구     218     209     206     210
# 13   도봉구     335     317     297     285
# 14   노원구     747     740     718     684
# 15   은평구     521     525     519     509
# 16  서대문구     345     346     348     342
# 17   마포구     644     683     689     692
# 18   양천구    1062    1037    1008     979
# 19   강서구     707     693     694     697
# 20   구로구     427     406     394     386
# 21   금천구     222     224     212     208
# 22  영등포구     467     446     445     440
# 23   동작구     458     465     471     487
# 24   관악구     450     443     431     434
# 25   서초구    1130    1119    1148    1146
# ...

# %%
a.set_index("자치구별",inplace=True)

# %%
academy=a

# %%
academy=academy.astype(int)

# %%
academy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 종로구 to 강동구
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   2018학원수  25 non-null     int32
#  1   2019학원수  25 non-null     int32
#  2   2020학원수  25 non-null     int32
#  3   2021학원수  25 non-null     int32
# dtypes: int32(4)
# memory usage: 600.0+ bytes

# %%
academy.to_csv("C:\\Users\\owner\\team project\\전처리 완\\academy.csv")
