# %% [markdown]
# # 서울시 지하철 데이터
# ## 자치구별 역 정보 및 수

# %%
import pandas as pd
import re

# %%
s=pd.read_csv("C:\\Users\\owner\\team project\\raw data\\서울교통공사_자치구별지하철역정보_20221130.csv",encoding="euc-kr")

# %%
s
# Out:
#     연번   자치구                                             역명(호선)  역수
# 0    1   강남구  삼성(2), 선릉(2), 역삼(2), 강남(2), 압구정(3), 신사(3), 매봉(...  21
# 1    2   강동구  천호(5), 강동(5), 길동(5), 굽은다리(5), 명일(5), 고덕(5), 상일...  14
# 2    3   강북구                             수유(4), 미아(4), 미아사거리(4)   3
# 3    4   강서구  방화(5), 개화산(5), 김포공항(5), 송정(5), 마곡(5), 발산(5), 우...   9
# 4    5   관악구                     낙성대(2), 서울대입구(2), 봉천(2), 신림(2)   4
# 5    6   광진구  건대입구(2), 구의(2), 강변(2), 군자(5), 아차산(5), 광나루(5), ...  11
# 6    7   구로구  구로디지털단지(2), 대림(2), 신도림(2), 도림천(2), 남구로(7), 천왕(...   7
# 7    8   금천구                                         가산디지털단지(7)   1
# 8    9   노원구  당고개(4), 상계(4), 노원(4), 석계(6), 태릉입구(6), 화랑대(6), ...  13
# 9   10   도봉구                               창동(4), 쌍문(4), 도봉산(7)   3
# 10  11  동대문구      신설동(1), 제기동(1), 청량리(1), 용두(2), 신설동(2), 장한평(5)   6
# 11  12   동작구  사당(2), 신대방(2), 동작(4), 이수(4), 사당(4), 이수(7), 남성(...  12
# 12  13   마포구  합정(2), 홍대입구(2), 신촌(2), 이대(2), 아현(2), 마포(5), 공덕...  16
# ...

# %%
s = s[ s['자치구'].str.match(r'^[가-힣]+구$') ]

# %%
s
# Out:
#     연번   자치구                                             역명(호선)  역수
# 0    1   강남구  삼성(2), 선릉(2), 역삼(2), 강남(2), 압구정(3), 신사(3), 매봉(...  21
# 1    2   강동구  천호(5), 강동(5), 길동(5), 굽은다리(5), 명일(5), 고덕(5), 상일...  14
# 2    3   강북구                             수유(4), 미아(4), 미아사거리(4)   3
# 3    4   강서구  방화(5), 개화산(5), 김포공항(5), 송정(5), 마곡(5), 발산(5), 우...   9
# 4    5   관악구                     낙성대(2), 서울대입구(2), 봉천(2), 신림(2)   4
# 5    6   광진구  건대입구(2), 구의(2), 강변(2), 군자(5), 아차산(5), 광나루(5), ...  11
# 6    7   구로구  구로디지털단지(2), 대림(2), 신도림(2), 도림천(2), 남구로(7), 천왕(...   7
# 7    8   금천구                                         가산디지털단지(7)   1
# 8    9   노원구  당고개(4), 상계(4), 노원(4), 석계(6), 태릉입구(6), 화랑대(6), ...  13
# 9   10   도봉구                               창동(4), 쌍문(4), 도봉산(7)   3
# 10  11  동대문구      신설동(1), 제기동(1), 청량리(1), 용두(2), 신설동(2), 장한평(5)   6
# 11  12   동작구  사당(2), 신대방(2), 동작(4), 이수(4), 사당(4), 이수(7), 남성(...  12
# 12  13   마포구  합정(2), 홍대입구(2), 신촌(2), 이대(2), 아현(2), 마포(5), 공덕...  16
# ...

# %%
del s["연번"]

# %%
s
# Out:
#      자치구                                             역명(호선)  역수
# 0    강남구  삼성(2), 선릉(2), 역삼(2), 강남(2), 압구정(3), 신사(3), 매봉(...  21
# 1    강동구  천호(5), 강동(5), 길동(5), 굽은다리(5), 명일(5), 고덕(5), 상일...  14
# 2    강북구                             수유(4), 미아(4), 미아사거리(4)   3
# 3    강서구  방화(5), 개화산(5), 김포공항(5), 송정(5), 마곡(5), 발산(5), 우...   9
# 4    관악구                     낙성대(2), 서울대입구(2), 봉천(2), 신림(2)   4
# 5    광진구  건대입구(2), 구의(2), 강변(2), 군자(5), 아차산(5), 광나루(5), ...  11
# 6    구로구  구로디지털단지(2), 대림(2), 신도림(2), 도림천(2), 남구로(7), 천왕(...   7
# 7    금천구                                         가산디지털단지(7)   1
# 8    노원구  당고개(4), 상계(4), 노원(4), 석계(6), 태릉입구(6), 화랑대(6), ...  13
# 9    도봉구                               창동(4), 쌍문(4), 도봉산(7)   3
# 10  동대문구      신설동(1), 제기동(1), 청량리(1), 용두(2), 신설동(2), 장한평(5)   6
# 11   동작구  사당(2), 신대방(2), 동작(4), 이수(4), 사당(4), 이수(7), 남성(...  12
# 12   마포구  합정(2), 홍대입구(2), 신촌(2), 이대(2), 아현(2), 마포(5), 공덕...  16
# 13  서대문구              충정로(2), 홍제(3), 무악재(3), 독립문(3), 충정로(5)   5
# ...

# %%
s.columns=("자치구별","역명(호선)","역개수")

# %%
s.set_index("자치구별",inplace=True)

# %%
s.to_csv("C:\\Users\\owner\\team project\\전처리 완\\station.csv")
