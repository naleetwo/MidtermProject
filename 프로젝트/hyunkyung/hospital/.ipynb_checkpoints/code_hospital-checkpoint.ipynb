# %%
import numpy as np
import pandas as pd
import re

# %%
hos_2021=pd.read_csv('C:/acorn/midproject/hospital/data/의료기관(구별)(2010년+이후)_20230413094616.csv', index_col=False, header=2)

# %%
hos_2021
# Out:
#     자치구별(1)  자치구별(2)     소계   소계.1 종합병원 종합병원.1   병원   병원.1    의원  의원.1  ...  \
# 0   자치구별(1)  자치구별(2)    병원수    병상수  병원수    병상수  병원수    병상수   병원수   병상수  ...
# 1       서울시       소계  18261  91735   56  33806  220  16296  9145  9447  ...
# 2       서울시      종로구    489   3636    4   2996    2    228   198   104  ...
# 3       서울시       중구    572   1286    2    804    3    239   240   173  ...
# 4       서울시      용산구    323    895    1    725    2     80   150    79  ...
# 5       서울시      성동구    460   1881    1    855    6    388   225   120  ...
# 6       서울시      광진구    559   2622    2   1097    5    431   275   422  ...
# 7       서울시     동대문구    596   5313    4   1725   11   1001   261   417  ...
# 8       서울시      중랑구    535   3320    3   1057   13   1015   247   568  ...
# 9       서울시      성북구    533   3519    1   1048    6    517   252   370  ...
# 10      서울시      강북구    467   2299    1    201    8    795   224   379  ...
# ...

# %%
del hos_2021['자치구별(1)']

# %%
hos_2021.columns
# Out:
# Index(['자치구별(2)', '소계', '소계.1', '종합병원', '종합병원.1', '병원', '병원.1', '의원', '의원.1',
#        '부속병의원', '부속병의원.1', '요양병원', '요양병원.1', '노인전문병원', '노인전문병원.1', '결핵병원',
#        '결핵병원.1', '정신병원', '정신병원.1', '치과병원', '치과병원.1', '치과의원', '치과의원.1', '한방병원',
#        '한방병원.1', '한방의원', '한방의원.1', '조산원', '조산원.1'],
#       dtype='object')

# %%
# newcolname=[]

#newcolname=[if ]

for i in hos_2021.columns :
    if '.1' in i : 
        del hos_2021[i]
#    newcolname.append(re.sub('[.][0-9]', '병상수', i))

# %%
hos_2021.columns
# Out:
# Index(['자치구별(2)', '소계', '종합병원', '병원', '의원', '부속병의원', '요양병원', '노인전문병원', '결핵병원',
#        '정신병원', '치과병원', '치과의원', '한방병원', '한방의원', '조산원'],
#       dtype='object')

# %%
hos_2021
# Out:
#     자치구별(2)     소계 종합병원   병원    의원 부속병의원 요양병원 노인전문병원 결핵병원 정신병원 치과병원  치과의원  \
# 0   자치구별(2)    병원수  병원수  병원수   병원수   병원수  병원수    병원수  병원수  병원수  병원수   병원수
# 1        소계  18261   56  220  9145    64  120      4    1   12   60  4887
# 2       종로구    489    4    2   198     8    1      0    0    0    1   151
# 3        중구    572    2    3   240    16    0      0    0    0    6   205
# 4       용산구    323    1    2   150     1    0      0    0    0    0   105
# 5       성동구    460    1    6   225     0    3      0    0    0    1   125
# 6       광진구    559    2    5   275     0    2      0    0    0    2   152
# 7      동대문구    596    4   11   261     0    7      0    0    2    4   154
# 8       중랑구    535    3   13   247     0    2      0    0    1    0   159
# 9       성북구    533    1    6   252     1    6      1    0    0    1   148
# 10      강북구    467    1    8   224     0    6      0    0    0    1   131
# 11      도봉구    366    1    5   164     0    5      1    0    3    1   102
# ...

# %%
hos_2021.drop(index=[0, 1], inplace=True)

# %%
hos_2021
# Out:
#    자치구별(2)    소계 종합병원  병원    의원 부속병의원 요양병원 노인전문병원 결핵병원 정신병원 치과병원 치과의원 한방병원  \
# 2      종로구   489    4   2   198     8    1      0    0    0    1  151    1
# 3       중구   572    2   3   240    16    0      0    0    0    6  205    1
# 4      용산구   323    1   2   150     1    0      0    0    0    0  105    0
# 5      성동구   460    1   6   225     0    3      0    0    0    1  125    0
# 6      광진구   559    2   5   275     0    2      0    0    0    2  152    2
# 7     동대문구   596    4  11   261     0    7      0    0    2    4  154    2
# 8      중랑구   535    3  13   247     0    2      0    0    1    0  159    1
# 9      성북구   533    1   6   252     1    6      1    0    0    1  148    1
# 10     강북구   467    1   8   224     0    6      0    0    0    1  131    0
# 11     도봉구   366    1   5   164     0    5      1    0    3    1  102    2
# 12     노원구   737    3   6   363     0    6      0    0    0    3  202    3
# ...

# %%
hos_2021=hos_2021[['자치구별(2)', '소계']]

# %%
hos_2021
# Out:
#    자치구별(2)    소계
# 2      종로구   489
# 3       중구   572
# 4      용산구   323
# 5      성동구   460
# 6      광진구   559
# 7     동대문구   596
# 8      중랑구   535
# 9      성북구   533
# 10     강북구   467
# 11     도봉구   366
# 12     노원구   737
# 13     은평구   688
# 14    서대문구   437
# 15     마포구   762
# 16     양천구   651
# 17     강서구   887
# 18     구로구   583
# 19     금천구   356
# 20    영등포구   793
# 21     동작구   595
# 22     관악구   710
# 23     서초구  1306
# 24     강남구  2790
# 25     송파구  1214
# 26     강동구   852

# %%
hos_2021.set_index('자치구별(2)', inplace=True)

# %%
hos_2021
# Out:
#            소계
# 자치구별(2)
# 종로구       489
# 중구        572
# 용산구       323
# 성동구       460
# 광진구       559
# 동대문구      596
# 중랑구       535
# 성북구       533
# 강북구       467
# 도봉구       366
# 노원구       737
# 은평구       688
# 서대문구      437
# 마포구       762
# 양천구       651
# 강서구       887
# 구로구       583
# 금천구       356
# 영등포구      793
# 동작구       595
# 관악구       710
# 서초구      1306
# 강남구      2790
# 송파구      1214
# 강동구       852

# %%
hos_2021=hos_2021.reset_index()

# %%
hos_2021
# Out:
#    자치구별(2)    소계
# 0      종로구   489
# 1       중구   572
# 2      용산구   323
# 3      성동구   460
# 4      광진구   559
# 5     동대문구   596
# 6      중랑구   535
# 7      성북구   533
# 8      강북구   467
# 9      도봉구   366
# 10     노원구   737
# 11     은평구   688
# 12    서대문구   437
# 13     마포구   762
# 14     양천구   651
# 15     강서구   887
# 16     구로구   583
# 17     금천구   356
# 18    영등포구   793
# 19     동작구   595
# 20     관악구   710
# 21     서초구  1306
# 22     강남구  2790
# 23     송파구  1214
# 24     강동구   852

# %%
hos_2021.rename(columns={'자치구별(2)':'자치구별', '소계':'2021병원수'}, inplace=True)

# %%
hos_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   자치구별     25 non-null     object
#  1   2021병원수  25 non-null     object
# dtypes: object(2)
# memory usage: 528.0+ bytes

# %%
hos_2021['2021병원수'] = hos_2021['2021병원수'].astype('int')

# %%
hos_2021.loc[len(hos_2021)] = ['평균', hos_2021['2021병원수'].mean()]

# %%
hos_2021
# Out:
#     자치구별  2021병원수
# 0    종로구   489.00
# 1     중구   572.00
# 2    용산구   323.00
# 3    성동구   460.00
# 4    광진구   559.00
# 5   동대문구   596.00
# 6    중랑구   535.00
# 7    성북구   533.00
# 8    강북구   467.00
# 9    도봉구   366.00
# 10   노원구   737.00
# 11   은평구   688.00
# 12  서대문구   437.00
# 13   마포구   762.00
# 14   양천구   651.00
# 15   강서구   887.00
# 16   구로구   583.00
# 17   금천구   356.00
# 18  영등포구   793.00
# 19   동작구   595.00
# 20   관악구   710.00
# 21   서초구  1306.00
# 22   강남구  2790.00
# 23   송파구  1214.00
# 24   강동구   852.00
# 25    평균   730.44

# %%
hos_2021.to_csv('C:/acorn/midproject/hospital/data/final_2021_hospital.csv')

# %% [markdown]
# ## 2020년

# %%
hos_2020=pd.read_csv('C:/acorn/midproject/hospital/data/2020_의료기관(동별)_20230413094439.csv', index_col=False)

# %%
hos_2020
# Out:
#      동별(1)  동별(2)  의료기관별(1)  의료기관별(2)   2020 2020.1
# 0    동별(1)  동별(2)  의료기관별(1)  의료기관별(2)    병원수    병상수
# 1       합계     소계         계        소계  17916  89714
# 2       합계     소계         계      종합병원     56  33649
# 3       합계     소계         계        병원    228  18675
# 4       합계     소계         계        의원   8847   9573
# ..     ...    ...       ...       ...    ...    ...
# 245     합계    강동구         계      요양병원      7   1655
# 246     합계    강동구         계      치과병원      3      9
# 247     합계    강동구         계      치과의원    224      -
# 248     합계    강동구         계      한방병원      6    440
# 249     합계    강동구         계      한방의원    187    129
#
# [250 rows x 6 columns]

# %%
seoulgulist = [
    '강남구',
    '강동구',
    '강북구',
    '강서구',
    '관악구',
    '광진구',
    '구로구',
    '금천구',
    '노원구',
    '도봉구',
    '동대문구',
    '동작구',
    '마포구',
    '서대문구',
    '서초구',
    '성동구',
    '성북구',
    '송파구',
    '양천구',
    '영등포구',
    '용산구',
    '은평구',
    '종로구',
    '중구',
    '중랑구'
]

# %%
seoulgu = pd.DataFrame(seoulgulist, columns=['자치구별'])

# %%
seoulgu
# Out:
#     자치구별
# 0    강남구
# 1    강동구
# 2    강북구
# 3    강서구
# 4    관악구
# 5    광진구
# 6    구로구
# 7    금천구
# 8    노원구
# 9    도봉구
# 10  동대문구
# 11   동작구
# 12   마포구
# 13  서대문구
# 14   서초구
# 15   성동구
# 16   성북구
# 17   송파구
# 18   양천구
# 19  영등포구
# 20   용산구
# 21   은평구
# 22   종로구
# 23    중구
# 24   중랑구

# %%
hos_2020.loc[(hos_2020['동별(2)'] == '종로구') & (hos_2020['의료기관별(2)']=='소계')]
# Out:
#    동별(1) 동별(2) 의료기관별(1) 의료기관별(2) 2020 2020.1
# 15    합계   종로구        계       소계  494   3317

# %%
hos_2020_final=pd.DataFrame()

for i in seoulgu :
    hos_2020_final = hos_2020_final.append(hos_2020.loc[(hos_2020['동별(2)'] == i) & (hos_2020['의료기관별(2)']=='소계')])
# Out:
# C:\Users\khg08\AppData\Local\Temp\ipykernel_35256\1645646749.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hos_2020_final = hos_2020_final.append(hos_2020.loc[(hos_2020['동별(2)'] == i) & (hos_2020['의료기관별(2)']=='소계')])

# %%
hos_2020_final
# Out:
# Empty DataFrame
# Columns: [동별(1), 동별(2), 의료기관별(1), 의료기관별(2), 2020, 2020.1]
# Index: []
