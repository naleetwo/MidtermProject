# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 데이터 출처
#     - https://data.seoul.go.kr/dataList/201/S/2/datasetView.do

# %%
data1=pd.read_csv("C:\\Users\\owner\\team project\\초등학교_20230417163349.csv")

# %%
data1
# Out:
#     자치구별(1)  자치구별(2)     2018     2019     2020     2021     2022
# 0   자치구별(1)  자치구별(2)  학교수 (개)  학교수 (개)  학교수 (개)  학교수 (개)  학교수 (개)
# 1        합계       소계      603      607      607      607      609
# 2        합계      종로구       13       13       13       13       13
# 3        합계       중구       12       12       12       12       12
# 4        합계      용산구       15       15       15       15       15
# 5        합계      성동구       21       21       21       21       21
# 6        합계      광진구       22       22       22       22       22
# 7        합계     동대문구       21       21       21       21       21
# 8        합계      중랑구       23       23       23       23       24
# 9        합계      성북구       29       29       29       29       29
# 10       합계      강북구       14       14       14       14       14
# 11       합계      도봉구       23       23       23       23       23
# 12       합계      노원구       42       42       42       42       42
# ...

# %%
# 필요없는 컬럼제거
del data1["자치구별(1)"]

# %%
data1
# Out:
#     자치구별(2)     2018     2019     2020     2021     2022
# 0   자치구별(2)  학교수 (개)  학교수 (개)  학교수 (개)  학교수 (개)  학교수 (개)
# 1        소계      603      607      607      607      609
# 2       종로구       13       13       13       13       13
# 3        중구       12       12       12       12       12
# 4       용산구       15       15       15       15       15
# 5       성동구       21       21       21       21       21
# 6       광진구       22       22       22       22       22
# 7      동대문구       21       21       21       21       21
# 8       중랑구       23       23       23       23       24
# 9       성북구       29       29       29       29       29
# 10      강북구       14       14       14       14       14
# 11      도봉구       23       23       23       23       23
# 12      노원구       42       42       42       42       42
# 13      은평구       30       31       31       30       30
# 14     서대문구       19       19       19       19       19
# ...

# %%
# 컬럼명 재지정
data1.columns=["자치구별","2018학교수", "2019학교수", "2020학교수", "2021학교수", "2022학교수"]

# %%
# 자치구별 컬럼 인덱스 지정
data1.set_index("자치구별",inplace=True)

# %%
# 필요없는 정보 제거(자치구별(2),소계)
data1.drop("자치구별(2)",inplace=True)
data1.drop("소계",inplace=True)

# %%
data1
# Out:
#      2018학교수 2019학교수 2020학교수 2021학교수 2022학교수
# 자치구별
# 종로구       13      13      13      13      13
# 중구        12      12      12      12      12
# 용산구       15      15      15      15      15
# 성동구       21      21      21      21      21
# 광진구       22      22      22      22      22
# 동대문구      21      21      21      21      21
# 중랑구       23      23      23      23      24
# 성북구       29      29      29      29      29
# 강북구       14      14      14      14      14
# 도봉구       23      23      23      23      23
# 노원구       42      42      42      42      42
# 은평구       30      31      31      30      30
# 서대문구      19      19      19      19      19
# 마포구       22      22      22      22      22
# 양천구       30      30      30      30      30
# 강서구       36      36      35      35      35
# 구로구       24      26      26      26      26
# 금천구       18      18      18      18      18
# 영등포구      23      23      23      23      23
# 동작구       21      21      21      21      21
# ...

# %%
# 데이터타입 정수형으로 변환
data1=data1.astype(int)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 종로구 to 강동구
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   2018학교수  25 non-null     int32
#  1   2019학교수  25 non-null     int32
#  2   2020학교수  25 non-null     int32
#  3   2021학교수  25 non-null     int32
#  4   2022학교수  25 non-null     int32
# dtypes: int32(5)
# memory usage: 700.0+ bytes

# %%
data1.to_csv("C:\\Users\\owner\\team project\\전처리 완\\ele_school.csv")
